# %% [markdown]
# ## This notebook contains:
# ### 01. Import libraries
# ### 02. Import and explore rent data
# ### 03. Deal with missing and irrelevant data
# ### 04. Investigate and correct anomalies
#    #### 04a. Total rent anomalies
#    #### 04b. Base rent anomalies
#    #### 04c. Year constructed anomalies
#    #### 04d. Living space (size) anomalies
#    #### 04e. Number of rooms anomalies
#    #### 04f. Floor anomalies
#    #### 04g. PLZ anomalies
#    #### 04h. Update and copy descriptive stats
# ### 05. Address mixed-type data
# ### 06. Check for duplicates
# ### 07. Create new price per unit variable
# ### 08. Final checks and export

# %% [markdown]
# # 01. Import libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import and explore rent data

# %%
# create shortcut for data imports
path = r'../rawData'

# %%
# import data 
df = pd.read_csv(os.path.join(path, 'immo_data.csv'), index_col = False)

# %%
df.head()
# Out:
#                 regio1  serviceCharge                     heatingType  \
# 0  Nordrhein_Westfalen         245.00                 central_heating
# 1      Rheinland_Pfalz         134.00  self_contained_central_heating
# 2              Sachsen         255.00                   floor_heating
# 3              Sachsen          58.15                district_heating
# 4               Bremen         138.00  self_contained_central_heating
#
#   telekomTvOffer  telekomHybridUploadSpeed  newlyConst  balcony  picturecount  \
# 0  ONE_YEAR_FREE                       NaN       False    False             6
# 1  ONE_YEAR_FREE                       NaN       False     True             8
# 2  ONE_YEAR_FREE                      10.0        True     True             8
# 3  ONE_YEAR_FREE                       NaN       False     True             9
# 4            NaN                       NaN       False     True            19
#
#    pricetrend  telekomUploadSpeed  ...               regio2  \
# 0        4.62                10.0  ...             Dortmund
# 1        3.47                10.0  ...    Rhein_Pfalz_Kreis
# 2        2.72                 2.4  ...              Dresden
# 3        1.53                40.0  ...  Mittelsachsen_Kreis
# 4        2.46                 NaN  ...               Bremen
#
#                        regio3  \
# 0                     Schüren
# 1              Böhl_Iggelheim
# 2  Äußere_Neustadt_Antonstadt
# 3                    Freiberg
# 4           Neu_Schwachhausen
#
#                                          description  \
# 0  Die ebenerdig zu erreichende Erdgeschosswohnun...
# 1  Alles neu macht der Mai – so kann es auch für ...
# 2  Der Neubau entsteht im Herzen der Dresdner Neu...
# 3  Abseits von Lärm und Abgasen in Ihre neue Wohn...
# 4  Es handelt sich hier um ein saniertes Mehrfami...
#
#                                           facilities heatingCosts  \
# 0  Die Wohnung ist mit Laminat ausgelegt. Das Bad...          NaN
# 1                                                NaN          NaN
# 2  * 9 m² Balkon\n* Bad mit bodengleicher Dusche,...          NaN
# 3                                                NaN        87.23
# 4  Diese Wohnung wurde neu saniert und ist wie fo...          NaN
#
#    energyEfficiencyClass lastRefurbish  electricityBasePrice  \
# 0                    NaN           NaN                   NaN
# 1                    NaN        2019.0                   NaN
# 2                    NaN           NaN                   NaN
# 3                    NaN           NaN                   NaN
# 4                    NaN           NaN                   NaN
#
#    electricityKwhPrice   date
# 0                  NaN  May19
# 1                  NaN  May19
# 2                  NaN  Oct19
# 3                  NaN  May19
# 4                  NaN  Feb20
#
# [5 rows x 49 columns]

# %%
df.shape
# Out:
# (268850, 49)

# %%
# on how many distinct dates were data collected?
df['date'].describe()
# Out:
# count     268850
# unique         4
# top        Feb20
# freq       79276
# Name: date, dtype: object

# %%
# are all states represented in the data?
df['regio1'].unique()
# Out:
# array(['Nordrhein_Westfalen', 'Rheinland_Pfalz', 'Sachsen', 'Bremen',
#        'Schleswig_Holstein', 'Baden_Württemberg', 'Thüringen', 'Hessen',
#        'Niedersachsen', 'Bayern', 'Hamburg', 'Sachsen_Anhalt',
#        'Mecklenburg_Vorpommern', 'Berlin', 'Brandenburg', 'Saarland'],
#       dtype=object)

# %%
pd.options.display.max_columns = 40

# %% [markdown]
# # 03. Deal with missing and irrelevant data

# %%
# are there any entirely blank rows in the df?
df.isnull().all(axis=1).sum()
# Out:
# 0

# %%
# count NaN in each row
df.isna().sum()
# Out:
# regio1                           0
# serviceCharge                 6909
# heatingType                  44856
# telekomTvOffer               32619
# telekomHybridUploadSpeed    223830
# newlyConst                       0
# balcony                          0
# picturecount                     0
# pricetrend                    1832
# telekomUploadSpeed           33358
# totalRent                    40517
# yearConstructed              57045
# scoutId                          0
# noParkSpaces                175798
# firingTypes                  56964
# hasKitchen                       0
# geo_bln                          0
# cellar                           0
# yearConstructedRange         57045
# baseRent                         0
# houseNumber                  71018
# livingSpace                      0
# geo_krs                          0
# condition                    68489
# interiorQual                112665
# petsAllowed                 114573
# street                           0
# streetPlain                  71013
# lift                             0
# baseRentRange                    0
# typeOfFlat                   36614
# geo_plz                          0
# noRooms                          0
# thermalChar                 106506
# floor                        51309
# numberOfFloors               97732
# noRoomsRange                     0
# garden                           0
# livingSpaceRange                 0
# regio2                           0
# regio3                           0
# description                  19747
# facilities                   52924
# heatingCosts                183332
# energyEfficiencyClass       191063
# lastRefurbish               188139
# electricityBasePrice        222004
# electricityKwhPrice         222004
# date                             0
# dtype: int64

# %% [markdown]
# I'll delete all columns with over 33% missing data, columns that contain the same information as other columns, and columns that aren't relevant to my analysis.

# %%
df_trim = df.drop(['serviceCharge', 'telekomTvOffer', 'telekomHybridUploadSpeed', 'telekomUploadSpeed', 'noParkSpaces', 'interiorQual', 'geo_bln', 'geo_krs', 'petsAllowed', 'thermalChar', 'numberOfFloors', 'heatingCosts', 'energyEfficiencyClass', 'houseNumber', 'streetPlain', 'lastRefurbish', 'electricityBasePrice', 'electricityKwhPrice', 'facilities'], axis=1)

# %%
# check work
df_trim.head()
# Out:
#                 regio1                     heatingType  newlyConst  balcony  \
# 0  Nordrhein_Westfalen                 central_heating       False    False
# 1      Rheinland_Pfalz  self_contained_central_heating       False     True
# 2              Sachsen                   floor_heating        True     True
# 3              Sachsen                district_heating       False     True
# 4               Bremen  self_contained_central_heating       False     True
#
#    picturecount  pricetrend  totalRent  yearConstructed    scoutId  \
# 0             6        4.62      840.0           1965.0   96107057
# 1             8        3.47        NaN           1871.0  111378734
# 2             8        2.72     1300.0           2019.0  113147523
# 3             9        1.53        NaN           1964.0  108890903
# 4            19        2.46      903.0           1950.0  114751222
#
#         firingTypes  hasKitchen  cellar  yearConstructedRange  baseRent  \
# 0               oil       False    True                   2.0     595.0
# 1               gas       False   False                   1.0     800.0
# 2               NaN       False    True                   9.0     965.0
# 3  district_heating       False   False                   2.0     343.0
# 4               gas       False   False                   1.0     765.0
#
#    livingSpace       condition                       street   lift  \
# 0        86.00       well_kept   Sch&uuml;ruferstra&szlig;e  False
# 1        89.00     refurbished               no_information  False
# 2        83.80  first_time_use                    Turnerweg   True
# 3        58.15             NaN  Gl&uuml;ck-Auf-Stra&szlig;e  False
# 4        84.97     refurbished  Hermann-Henrich-Meier-Allee  False
#
#    baseRentRange    typeOfFlat  geo_plz  noRooms  floor  noRoomsRange  garden  \
# 0              4  ground_floor    44269      4.0    1.0             4    True
# 1              5  ground_floor    67459      3.0    NaN             3   False
# 2              6     apartment     1097      3.0    3.0             3   False
# 3              2         other     9599      3.0    3.0             3   False
# 4              5     apartment    28213      3.0    1.0             3   False
#
#    livingSpaceRange               regio2                      regio3  \
# 0                 4             Dortmund                     Schüren
# 1                 4    Rhein_Pfalz_Kreis              Böhl_Iggelheim
# 2                 4              Dresden  Äußere_Neustadt_Antonstadt
# 3                 2  Mittelsachsen_Kreis                    Freiberg
# 4                 4               Bremen           Neu_Schwachhausen
#
#                                          description   date
# 0  Die ebenerdig zu erreichende Erdgeschosswohnun...  May19
# 1  Alles neu macht der Mai – so kann es auch für ...  May19
# 2  Der Neubau entsteht im Herzen der Dresdner Neu...  Oct19
# 3  Abseits von Lärm und Abgasen in Ihre neue Wohn...  May19
# 4  Es handelt sich hier um ein saniertes Mehrfami...  Feb20

# %% [markdown]
# # 04. Investigate and correct anomalies

# %%
# rearrange columns to prioritize most important info
df_trim = df_trim[['regio1', 'baseRent', 'totalRent', 'pricetrend', 'livingSpace', 'geo_plz', 'picturecount', 'newlyConst', 'yearConstructed', 'scoutId', 'firingTypes', 'heatingType', 'hasKitchen', 'cellar', 'condition', 'street', 'lift', 'typeOfFlat', 'noRooms', 'floor', 'balcony', 'garden',
'baseRentRange', 'noRoomsRange', 'livingSpaceRange', 'yearConstructedRange', 'regio2', 'regio3', 'description', 'date']]

# %%
df_trim.head()
# Out:
#                 regio1  baseRent  totalRent  pricetrend  livingSpace  geo_plz  \
# 0  Nordrhein_Westfalen     595.0      840.0        4.62        86.00    44269
# 1      Rheinland_Pfalz     800.0        NaN        3.47        89.00    67459
# 2              Sachsen     965.0     1300.0        2.72        83.80     1097
# 3              Sachsen     343.0        NaN        1.53        58.15     9599
# 4               Bremen     765.0      903.0        2.46        84.97    28213
#
#    picturecount  newlyConst  yearConstructed    scoutId       firingTypes  \
# 0             6       False           1965.0   96107057               oil
# 1             8       False           1871.0  111378734               gas
# 2             8        True           2019.0  113147523               NaN
# 3             9       False           1964.0  108890903  district_heating
# 4            19       False           1950.0  114751222               gas
#
#                       heatingType  hasKitchen  cellar       condition  \
# 0                 central_heating       False    True       well_kept
# 1  self_contained_central_heating       False   False     refurbished
# 2                   floor_heating       False    True  first_time_use
# 3                district_heating       False   False             NaN
# 4  self_contained_central_heating       False   False     refurbished
#
#                         street   lift    typeOfFlat  noRooms  floor  balcony  \
# 0   Sch&uuml;ruferstra&szlig;e  False  ground_floor      4.0    1.0    False
# 1               no_information  False  ground_floor      3.0    NaN     True
# 2                    Turnerweg   True     apartment      3.0    3.0     True
# 3  Gl&uuml;ck-Auf-Stra&szlig;e  False         other      3.0    3.0     True
# 4  Hermann-Henrich-Meier-Allee  False     apartment      3.0    1.0     True
#
#    garden  baseRentRange  noRoomsRange  livingSpaceRange  \
# 0    True              4             4                 4
# 1   False              5             3                 4
# 2   False              6             3                 4
# 3   False              2             3                 2
# 4   False              5             3                 4
#
#    yearConstructedRange               regio2                      regio3  \
# 0                   2.0             Dortmund                     Schüren
# 1                   1.0    Rhein_Pfalz_Kreis              Böhl_Iggelheim
# 2                   9.0              Dresden  Äußere_Neustadt_Antonstadt
# 3                   2.0  Mittelsachsen_Kreis                    Freiberg
# 4                   1.0               Bremen           Neu_Schwachhausen
#
#                                          description   date
# 0  Die ebenerdig zu erreichende Erdgeschosswohnun...  May19
# 1  Alles neu macht der Mai – so kann es auch für ...  May19
# 2  Der Neubau entsteht im Herzen der Dresdner Neu...  Oct19
# 3  Abseits von Lärm und Abgasen in Ihre neue Wohn...  May19
# 4  Es handelt sich hier um ein saniertes Mehrfami...  Feb20

# %%
# view descriptive statistics
df_trim.describe()
# Out:
#            baseRent     totalRent     pricetrend    livingSpace  \
# count  2.688500e+05  2.283330e+05  267018.000000  268850.000000
# mean   6.941294e+02  9.013315e+02       3.389001      74.355548
# std    1.953602e+04  3.323833e+04       1.964874     254.759208
# min    0.000000e+00  0.000000e+00     -12.330000       0.000000
# 25%    3.380000e+02  4.698000e+02       2.000000      54.000000
# 50%    4.900000e+02  6.500000e+02       3.390000      67.320000
# 75%    7.990000e+02  9.850000e+02       4.570000      87.000000
# max    9.999999e+06  1.575154e+07      14.920000  111111.000000
#
#              geo_plz   picturecount  yearConstructed       scoutId  \
# count  268850.000000  268850.000000    211805.000000  2.688500e+05
# mean    37283.022235       9.791958      1966.400590  1.069697e+08
# std     27798.037296       6.408399        46.992207  1.250093e+07
# min       852.000000       0.000000      1000.000000  2.887174e+07
# 25%      9128.000000       6.000000      1950.000000  1.066910e+08
# 50%     38667.000000       9.000000      1973.000000  1.111584e+08
# 75%     57072.000000      13.000000      1996.000000  1.137688e+08
# max     99998.000000     121.000000      2090.000000  1.157117e+08
#
#              noRooms          floor  baseRentRange   noRoomsRange  \
# count  268850.000000  217541.000000  268850.000000  268850.000000
# mean        2.641261       2.122405       3.765256       2.571542
# std         2.633440       3.634934       2.214357       0.937594
# min         1.000000      -1.000000       1.000000       1.000000
# 25%         2.000000       1.000000       2.000000       2.000000
# 50%         3.000000       2.000000       3.000000       3.000000
# 75%         3.000000       3.000000       5.000000       3.000000
# max       999.990000     999.000000       9.000000       5.000000
#
#        livingSpaceRange  yearConstructedRange
# count     268850.000000         211805.000000
# mean           3.070790              3.714544
# std            1.407127              2.738134
# min            1.000000              1.000000
# 25%            2.000000              1.000000
# 50%            3.000000              3.000000
# 75%            4.000000              5.000000
# max            7.000000              9.000000

# %% [markdown]
# Descriptive statistics show a number of issues, namely suspiciously low and high values in baseRent, totalRent, livingSpace, yearsConstructed, noRooms (high numbers only) and floor (high numbers only).
# The basic procedure for each check involves locating very low or high values, copying them to an Excel spreadsheet, and using other column values (particularly the description) to see if the value appears plausible.
# I'll investigate high values in totalRent first.

# %% [markdown]
# ## 04a. Total rent anomalies

# %%
df_trim[df_trim['totalRent']> 10000.0]
# Out:
#                      regio1    baseRent    totalRent  pricetrend  livingSpace  \
# 8406      Baden_Württemberg  1234567.00   1234567.00        3.90        76.00
# 14123                Hessen    12000.00     13400.00        5.13       600.00
# 16832        Sachsen_Anhalt      460.29     63204.00        1.52        68.70
# 23490    Schleswig_Holstein      820.00    108000.00        3.90        86.61
# 38143               Hamburg    10500.00     11900.00         NaN       207.07
# 50706         Niedersachsen      184.00     19519.00        3.61        16.00
# 57237                Bayern    13000.00     15000.00        4.89       269.00
# 61094                Berlin    12000.00     15500.00        7.69       364.00
# 64109               Sachsen     9000.00     11250.00        3.80       387.00
# 71162                Bayern    10700.00     12900.00        7.43       277.00
# 79903   Nordrhein_Westfalen      350.00    485350.00        3.51        62.00
# 96351                Bayern    11400.00     12000.00        5.71       427.00
# 97927                Berlin      427.70     51570.00       10.17        32.90
# 109047    Baden_Württemberg      950.00   1150900.00        4.98       137.00
# 112744               Bayern    10700.00     11480.00        5.23       236.60
# 118653  Nordrhein_Westfalen    12000.00     13344.00        3.45       420.00
# 148017  Nordrhein_Westfalen    10440.00     12900.00        3.28       516.00
# 163402               Berlin    15000.00     15000.00        8.77       456.00
# 170816               Hessen    19329.00     20588.00        5.21       601.85
# 177289               Berlin    15800.00     19600.00        8.55       565.00
# 190283               Berlin    20000.00     26500.00        8.28       566.00
# 196419               Berlin    12000.00     13000.00        8.70       300.00
# 197378  Nordrhein_Westfalen      487.51     64651.00        2.42        79.00
# 209250               Berlin     1050.00     13500.00       11.01        79.60
# 223703               Berlin    11000.00     12300.00        8.70       403.00
# 225772               Berlin    16000.00     16800.00        8.55       456.00
# 228981               Berlin    16000.00     16800.00        8.55       456.00
# 239533      Rheinland_Pfalz     1325.00  15751535.00        4.66       125.00
# 240954       Sachsen_Anhalt      266.00     37600.00        0.75        49.00
# 241809               Berlin    12000.00     15500.00        6.26       364.63
# 250558               Bayern    17781.12     20466.12        7.43       362.88
# 255251       Sachsen_Anhalt     1050.00     11250.00        2.03       103.86
# 260259       Sachsen_Anhalt  1000000.00   1000000.00        2.22        10.00
# 266809               Berlin     9000.00     11100.00        6.15       520.00
#
#         geo_plz  picturecount  newlyConst  yearConstructed    scoutId  \
# 8406      68789            13       False              NaN  107360251
# 14123     60322             2       False           1900.0   98567656
# 16832     39108            17       False           1998.0  115270570
# 23490     22927            10       False           1979.0  114307164
# 38143     20457            20        True           2018.0  113610764
# 50706     30169            17       False           1851.0   49280854
# 57237     80538            12       False           2016.0  112740899
# 61094     14195            19       False           2008.0  108319408
# 64109      4103             6       False              NaN   96517534
# 71162     80333             5       False           2008.0  105945172
# 79903     44629            10       False           1910.0   93931906
# 96351     81675            17       False           2015.0  113645258
# 97927     10553             3       False              NaN   65562466
# 109047    72644            13       False              NaN   64355043
# 112744    81925            14        True           2019.0  114430810
# 118653    40545            16       False           2013.0   77264293
# 148017    44867             6       False              NaN  100150280
# 163402    10117            27       False           2012.0  102693974
# 170816    60322            11       False              NaN  114421851
# 177289    10117            35       False           2017.0  109618469
# 190283    10785            30       False           2004.0  112710749
# 196419    10179            14       False           1998.0  105015584
# 197378    42857             2       False           1963.0  109915375
# 209250    13357            12        True           2018.0  110834468
# 223703    10117            16       False           2008.0  105026202
# 225772    10117            30       False           2011.0  111089892
# 228981    10117            16       False           2012.0  110485699
# 239533    67434            16       False           2014.0   83412744
# 240954    38820             4       False           1987.0  115572304
# 241809    14195            18       False           2008.0  110089802
# 250558    80539            14       False           2015.0  107357527
# 255251     6110            21       False           1890.0  115285901
# 260259    39624             1       False              NaN   91194882
# 266809    14109            25       False           1920.0  107602674
#
#               firingTypes                     heatingType  hasKitchen  cellar  \
# 8406                  NaN                             NaN        True   False
# 14123                 gas  self_contained_central_heating       False   False
# 16832    district_heating                district_heating       False    True
# 23490                 oil                     oil_heating       False   False
# 38143                 NaN                district_heating       False    True
# 50706    district_heating                 central_heating        True    True
# 57237                 NaN                             NaN        True   False
# 61094                 gas                     gas_heating        True    True
# 64109   natural_gas_light                 central_heating        True   False
# 71162                 NaN                 central_heating        True    True
# 79903                 gas                 central_heating       False   False
# 96351                 gas                 central_heating        True    True
# 97927                 gas                 central_heating       False   False
# 109047                oil                 central_heating       False   False
# 112744   district_heating                   floor_heating        True    True
# 118653                gas                     gas_heating        True    True
# 148017  natural_gas_light                 central_heating        True   False
# 163402   district_heating                district_heating        True    True
# 170816                gas                     gas_heating       False   False
# 177289   district_heating                 central_heating        True    True
# 190283   district_heating                 central_heating        True   False
# 196419   district_heating                district_heating        True    True
# 197378                gas  self_contained_central_heating       False    True
# 209250                oil                 central_heating       False   False
# 223703   district_heating                 central_heating        True    True
# 225772   district_heating                 central_heating        True   False
# 228981   district_heating                 central_heating        True    True
# 239533                gas   combined_heat_and_power_plant       False    True
# 240954                NaN                 central_heating       False    True
# 241809                gas                   floor_heating        True    True
# 250558                NaN                             NaN        True   False
# 255251                gas                 central_heating       False    True
# 260259                NaN                             NaN       False   False
# 266809                gas                     gas_heating        True    True
#
#                                  condition                       street  \
# 8406                                   NaN                 Kastanienweg
# 14123                           negotiable     Auf der K&ouml;rnerwiese
# 16832                            well_kept            G._Hauptmann_Str.
# 23490                            well_kept             Ahrensfelder Weg
# 38143                       first_time_use               no_information
# 50706                      fully_renovated          Oeltzenstra&szlig;e
# 57237                                  NaN               no_information
# 61094                                  NaN               no_information
# 64109                      fully_renovated               no_information
# 71162                       mint_condition               no_information
# 79903                                  NaN                 Bismarckstr.
# 96351                       mint_condition               no_information
# 97927                      fully_renovated                    Ufnaustr.
# 109047                         refurbished               no_information
# 112744                      first_time_use               no_information
# 118653                      first_time_use               no_information
# 148017                     fully_renovated               no_information
# 163402                      first_time_use         Oberwallstra&szlig;e
# 170816  first_time_use_after_refurbishment             Hochstra&szlig;e
# 177289                                 NaN         Oberwallstra&szlig;e
# 190283                      mint_condition              Potsdamer Platz
# 196419                      mint_condition               no_information
# 197378                           well_kept                Schaller Str.
# 209250                      first_time_use                Gottschedstr.
# 223703                                 NaN         Oberwallstra&szlig;e
# 225772                      mint_condition         Oberwallstra&szlig;e
# 228981                         refurbished               no_information
# 239533                      mint_condition               no_information
# 240954                         refurbished   Erich-Weinert-Stra&szlig;e
# 241809                                 NaN               no_information
# 250558                                 NaN               no_information
# 255251  first_time_use_after_refurbishment  Albert-Schmidt-Stra&szlig;e
# 260259                                 NaN                Zu den Wiesen
# 266809                         refurbished               no_information
#
#          lift  typeOfFlat  noRooms  floor  balcony  garden  baseRentRange  \
# 8406    False   apartment      4.0    NaN     True   False              9
# 14123    True  maisonette     15.0    4.0     True   False              9
# 16832    True   apartment      2.0    2.0     True   False              3
# 23490   False   apartment      2.5    NaN    False   False              6
# 38143    True   apartment      5.0   23.0     True   False              9
# 50706   False         NaN      1.0    3.0     True    True              1
# 57237    True         NaN      6.0    NaN     True   False              9
# 61094    True   penthouse      4.0    3.0     True    True              9
# 64109   False         NaN     15.0    NaN    False   False              9
# 71162    True   apartment      4.0    4.0     True   False              9
# 79903   False   apartment      3.5    3.0    False   False              2
# 96351   False        loft      7.0    6.0     True   False              9
# 97927   False   apartment      1.0    4.0    False   False              3
# 109047  False   apartment      5.0    2.0     True    True              6
# 112744   True   penthouse      5.5    3.0     True    True              9
# 118653   True   penthouse      8.0    4.0     True   False              9
# 148017  False         NaN     18.0    NaN    False   False              9
# 163402   True       other      4.0    NaN     True   False              9
# 170816   True   penthouse      6.0    7.0     True   False              9
# 177289   True         NaN     12.0    NaN     True    True              9
# 190283   True   apartment     10.0   17.0    False   False              9
# 196419   True   apartment      4.0    3.0     True    True              9
# 197378  False         NaN      3.0    1.0     True   False              3
# 209250  False        loft      2.0    5.0     True   False              7
# 223703  False   apartment      4.0    0.0     True   False              9
# 225772   True   apartment      4.0    0.0     True   False              9
# 228981   True        loft      4.0    4.0     True    True              9
# 239533   True   apartment      3.0    2.0     True   False              7
# 240954  False   apartment      2.0    5.0    False   False              1
# 241809   True   penthouse      4.0    3.0     True    True              9
# 250558   True         NaN      5.0    NaN     True   False              9
# 255251   True  maisonette      5.0    4.0     True   False              7
# 260259  False       other      1.0    NaN    False   False              9
# 266809  False  maisonette     11.0    NaN     True    True              9
#
#         noRoomsRange  livingSpaceRange  yearConstructedRange  \
# 8406               4                 3                   NaN
# 14123              5                 7                   1.0
# 16832              2                 3                   5.0
# 23490              2                 4                   3.0
# 38143              5                 7                   9.0
# 50706              1                 1                   1.0
# 57237              5                 7                   9.0
# 61094              4                 7                   7.0
# 64109              5                 7                   NaN
# 71162              4                 7                   7.0
# 79903              3                 3                   1.0
# 96351              5                 7                   8.0
# 97927              1                 1                   NaN
# 109047             5                 6                   NaN
# 112744             5                 7                   9.0
# 118653             5                 7                   8.0
# 148017             5                 7                   NaN
# 163402             4                 7                   8.0
# 170816             5                 7                   NaN
# 177289             5                 7                   9.0
# 190283             5                 7                   6.0
# 196419             4                 7                   5.0
# 197378             3                 3                   2.0
# 209250             2                 3                   9.0
# 223703             4                 7                   7.0
# 225772             4                 7                   8.0
# 228981             4                 7                   8.0
# 239533             3                 6                   8.0
# 240954             2                 2                   4.0
# 241809             4                 7                   7.0
# 250558             5                 7                   8.0
# 255251             5                 5                   1.0
# 260259             1                 1                   NaN
# 266809             5                 7                   1.0
#
#                             regio2                     regio3  \
# 8406            Rhein_Neckar_Kreis             Sankt_Leon_Rot
# 14123            Frankfurt_am_Main               Westend_Nord
# 16832                    Magdeburg              Stadtfeld_Ost
# 23490               Stormarn_Kreis               Großhansdorf
# 38143                      Hamburg             Hamb._Altstadt
# 50706                     Hannover       Calenberger_Neustadt
# 57237                      München                      Lehel
# 61094                       Berlin  Schmargendorf_Wilmersdorf
# 64109                      Leipzig              Lausen_Grünau
# 71162                      München                Maxvorstadt
# 79903                        Herne                 Baukau_Ost
# 96351                      München                 Haidhausen
# 97927                       Berlin      Tiergarten_Tiergarten
# 109047             Esslingen_Kreis              Oberboihingen
# 112744                     München                Bogenhausen
# 118653                  Düsseldorf                 Oberkassel
# 148017                      Bochum                 Westenfeld
# 163402                      Berlin                Mitte_Mitte
# 170816           Frankfurt_am_Main                 Innenstadt
# 177289                      Berlin                Mitte_Mitte
# 190283                      Berlin      Tiergarten_Tiergarten
# 196419                      Berlin                Mitte_Mitte
# 197378                   Remscheid                 Kremenholl
# 209250                      Berlin            Wedding_Wedding
# 223703                      Berlin                Mitte_Mitte
# 225772                      Berlin                Mitte_Mitte
# 228981                      Berlin                Mitte_Mitte
# 239533  Neustadt_an_der_Weinstraße                  Kernstadt
# 240954                  Harz_Kreis                Halberstadt
# 241809                      Berlin  Schmargendorf_Wilmersdorf
# 250558                     München                Maxvorstadt
# 255251                 Halle_Saale        Südliche_Innenstadt
# 260259      Altmarkkreis_Salzwedel                  Güssefeld
# 266809                      Berlin         Wannsee_Zehlendorf
#
#                                               description   date
# 8406    Komplett eingerichtete Wohnung in 68789 St. Le...  Sep18
# 14123   Über die hellen, mit Granit verkleideten Trepp...  Oct19
# 16832   Modernes und gepflegtes Mehrfamilienhaus in  s...  Feb20
# 23490   Die angebotene 2½-Zimmer-Wohnung befindet sich...  Feb20
# 38143   Ultimate luxury living! Ein Angebot, wie es se...  Oct19
# 50706   Wir suchen einen engagierten Studenten (männli...  Sep18
# 57237   Die high-end-Wohnung befindet sich in einem te...  Oct19
# 61094   Die Villa „Grunewaldherz“ ist ein modernes Geb...  May19
# 64109   Unsere Firmenwohnungen sind nicht für Privatpe...  Feb20
# 71162   Exclusiver "City-Lifestyle" \n\nExklusive Luxu...  Sep18
# 79903   Diese helle 3,5 Zimmerwohnung mit zeitlos gefl...  Sep18
# 96351   Die exklusive Dachgeschoss-Terrassenwohnung be...  Oct19
# 97927   Zentral gelegener Altbau in Tiergarten-Moabit....  May19
# 109047  Die familienfreundliche Wohnung oder großzügig...  Feb20
# 112744  Das außergewöhnliche Neubauprojekt Flemingstra...  Feb20
# 118653  Dieses  Penthouse  ist  elegant und gleichzeit...  May19
# 148017  Unsere Firmenwohnungen sind nicht für Privatpe...  May19
# 163402  Das Townhouse wurde 2012 nach neusten technisc...  Sep18
# 170816  Ausgestattet mit hochwertigem Eichen-Parkett, ...  Feb20
# 177289  Dieses eindrucksvolle Townhouse überzeugt auf ...  May19
# 190283  Erleben Sie Wohnen auf höchstem Niveau, direkt...  Oct19
# 196419  Dieses Loft befindet sich direkt an der Grenze...  Sep18
# 197378  Das Gebäude, in dem die geräumige und helle Wo...  May19
# 209250  Hierbei handelt es sich um einen Erstbezug nac...  May19
# 223703  Das viergeschossige Stadthaus wurde von den Ar...  Sep18
# 225772  Eine neue Art des urbanen Wohnens in Verbindun...  May19
# 228981  Das hier angebotene Townhouse wurde im Jahr 20...  May19
# 239533  Eine Wohnung mit luxuriöser Ausstattung und ei...  Oct19
# 240954                                                NaN  Feb20
# 241809  Die Villa Grunewaldherz stellt seit ihrer Erri...  Oct19
# 250558  Dieses einzigartige, elegante und lichtdurchfl...  Sep18
# 255251  Bei diesem Objekt handelt es sich um ein 5 - s...  Feb20
# 260259  Dies ist eine Testanzeige von ImmobilienScout2...  May19
# 266809  Diese außerordentlich prachtvolle Zweiparteien...  May19

# %%
# create subset of entries with rent over 10,000
highRent = df_trim[df_trim['totalRent'] > 10000.0]

# %%
# copy to clipboard so I can view in Excel
highRent.to_clipboard()

# %% [markdown]
# I located a set of incorrect values that I'll need to impute with the median value for the specified region.

# %%
df_trim.loc[df_trim['regio1'] == 'Baden_Württemberg', 'totalRent'].median()
# Out:
# 1020.0

# %%
df_trim.loc[df_trim['regio1'] == 'Sachsen_Anhalt', 'totalRent'].median()
# Out:
# 464.0

# %%
df_trim.loc[df_trim['regio1'] == 'Schleswig_Holstein', 'totalRent'].median()
# Out:
# 755.0

# %%
df_trim.loc[df_trim['regio1'] == 'Niedersachsen', 'totalRent'].median()
# Out:
# 692.0

# %%
df_trim.loc[df_trim['regio1'] == 'Sachsen', 'totalRent'].median()
# Out:
# 480.0

# %%
df_trim.loc[df_trim['regio1'] == 'Nordrhein_Westfalen', 'totalRent'].median()
# Out:
# 660.0

# %%
df_trim.loc[df_trim['regio1'] == 'Berlin', 'totalRent'].median()
# Out:
# 1124.0

# %%
df_trim.loc[df_trim['regio1'] == 'Rheinland_Pfalz', 'totalRent'].median()
# Out:
# 780.0

# %%
# replace the incorrect values
df_trim = df_trim.replace({'totalRent': {1234567: 1020, 63204: 464, 108000: 755, 19519: 692, 11250: 480, 485350: 660, 51570: 1124, 1150900: 1020, 12900: 660, 64651: 660, 13500: 1124, 15751535: 780, 37600: 464, 1000000: 464}})

# %%
# view descriptive stats again to make sure the excessively high values are gone
df_trim['totalRent'].describe()
# Out:
# count    228333.000000
# mean        813.664872
# std         562.786596
# min           0.000000
# 25%         469.800000
# 50%         650.000000
# 75%         984.450000
# max       26500.000000
# Name: totalRent, dtype: float64

# %%
# investigate low rent values
df_trim[df_trim['totalRent']< 150.0]
# Out:
#                      regio1  baseRent  totalRent  pricetrend  livingSpace  \
# 1119                Sachsen     210.0        0.0       -0.65        49.80
# 1883    Nordrhein_Westfalen     295.0        0.0        4.28        40.00
# 4209                Sachsen     245.0        0.0        0.00        45.00
# 5035                Sachsen     240.0        0.0        0.97        50.00
# 5739                Sachsen     220.5        0.0       -0.65        63.11
# ...                     ...       ...        ...         ...          ...
# 263216              Sachsen     250.0        3.0        0.00        46.00
# 266209  Nordrhein_Westfalen     385.0        0.0        2.99        62.00
# 267867  Nordrhein_Westfalen     400.0        0.0        1.98        48.56
# 268067    Baden_Württemberg    1620.0        0.0         NaN       124.00
# 268185              Sachsen     504.0      112.0        0.94       112.06
#
#         geo_plz  picturecount  newlyConst  yearConstructed    scoutId  \
# 1119       9430            10       False           1973.0   94258021
# 1883      45130             6       False           1964.0  111407942
# 4209       9212            15       False           1930.0  105929235
# 5035       8280            13       False           1960.0  113014387
# 5739       9430             9       False           1989.0   94257790
# ...         ...           ...         ...              ...        ...
# 263216     8359             5       False           1950.0  110620002
# 266209    45145             4       False           1950.0  110666549
# 267867    42853             8       False              NaN  113704814
# 268067    69115             5       False           2014.0  106732585
# 268185     1558             9       False              NaN  111360957
#
#         firingTypes                     heatingType  hasKitchen  cellar  \
# 1119            gas                 central_heating       False    True
# 1883    electricity            night_storage_heater       False    True
# 4209            gas                 central_heating       False    True
# 5035            gas                 central_heating       False    True
# 5739    electricity  self_contained_central_heating       False    True
# ...             ...                             ...         ...     ...
# 263216          gas                             NaN       False    True
# 266209          gas  self_contained_central_heating       False    True
# 267867          gas  self_contained_central_heating        True    True
# 268067          NaN                district_heating       False   False
# 268185          NaN                             NaN        True    True
#
#              condition               street   lift    typeOfFlat  noRooms  \
# 1119               NaN       no_information  False     apartment      2.0
# 1883         well_kept         Brigittastr.  False     apartment      1.0
# 4209               NaN       no_information  False     apartment      2.0
# 5035         well_kept       no_information  False     apartment      2.0
# 5739               NaN       no_information  False     apartment      3.0
# ...                ...                  ...    ...           ...      ...
# 263216             NaN       no_information  False  ground_floor      2.0
# 266209       well_kept         Berlinerstr.  False         other      2.0
# 267867       well_kept       no_information  False     apartment      2.0
# 268067  mint_condition       no_information  False     apartment      4.0
# 268185     refurbished  Hermannstra&szlig;e  False  ground_floor      3.0
#
#         floor  balcony  garden  baseRentRange  noRoomsRange  livingSpaceRange  \
# 1119      1.0    False    True              1             2                 2
# 1883      2.0     True   False              1             1                 1
# 4209      2.0    False    True              1             2                 2
# 5035      1.0    False    True              1             2                 2
# 5739      3.0     True    True              1             3                 3
# ...       ...      ...     ...            ...           ...               ...
# 263216    NaN    False   False              1             2                 2
# 266209    2.0     True   False              2             2                 3
# 267867    4.0    False   False              2             2                 2
# 268067    3.0    False   False              8             4                 6
# 268185    0.0    False    True              4             3                 5
#
#         yearConstructedRange           regio2                   regio3  \
# 1119                     3.0  Erzgebirgskreis                  Drebach
# 1883                     2.0            Essen             Rüttenscheid
# 4209                     1.0    Zwickau_Kreis       Limbach_Oberfrohna
# 5035                     2.0  Erzgebirgskreis                      Aue
# 5739                     4.0  Erzgebirgskreis                  Drebach
# ...                      ...              ...                      ...
# 263216                   1.0  Erzgebirgskreis  Breitenbrunn/Erzgebirge
# 266209                   1.0            Essen              Frohnhausen
# 267867                   NaN        Remscheid               Innenstadt
# 268067                   8.0       Heidelberg                Bahnstadt
# 268185                   NaN     Meißen_Kreis               Großenhain
#
#                                               description   date
# 1119    Diese gemütliche 2-Raumwohnung befindet sich i...  Oct19
# 1883    2. Obergeschoss in einem gepflegten Mehrfamili...  May19
# 4209    Im 2.Obergeschoss des schönen Mehrfamilienhaus...  May19
# 5035    Diese geräumige 2-Raumwohnung befindet sich im...  Feb20
# 5739                                                  NaN  Feb20
# ...                                                   ...    ...
# 263216  Vermietet wird hier eine schöne und ruhig gele...  May19
# 266209  Gepflegtes Mehrfamilienhaus.\n\n- Wohnzimmer\n...  May19
# 267867  Die Wohnung ist ein echter Volltreffer, denn s...  Oct19
# 268067  Diese geräumige und charmante 4- Zimmer-Wohnun...  Sep18
# 268185  Das sanierte, 3-geschossige Objekt befindet in...  May19
#
# [360 rows x 30 columns]

# %%
# for values of zero, insert value from the base rent column
total_rent = df_trim['totalRent']
total_rent.replace(to_replace = 0,  method='ffill', inplace=True)

# %%
# check that no zeroes remain
df_trim[df_trim['totalRent'] == 0.0]
# Out:
# Empty DataFrame
# Columns: [regio1, baseRent, totalRent, pricetrend, livingSpace, geo_plz, picturecount, newlyConst, yearConstructed, scoutId, firingTypes, heatingType, hasKitchen, cellar, condition, street, lift, typeOfFlat, noRooms, floor, balcony, garden, baseRentRange, noRoomsRange, livingSpaceRange, yearConstructedRange, regio2, regio3, description, date]
# Index: []

# %% [markdown]
# Follow the same procedure for baseRent, replacing zeroes with totalRent values.

# %%
df_trim[df_trim['baseRent'] == 0.0]
# Out:
#                      regio1  baseRent  totalRent  pricetrend  livingSpace  \
# 201                 Sachsen       0.0        NaN        0.00        45.34
# 1377               Saarland       0.0      700.0        2.46        30.00
# 2045    Nordrhein_Westfalen       0.0      731.5        3.30        77.00
# 6911                 Bayern       0.0      370.0        6.58        42.00
# 11130       Rheinland_Pfalz       0.0        NaN        3.86        20.00
# ...                     ...       ...        ...         ...          ...
# 254055    Baden_Württemberg       0.0      470.0        4.29         0.00
# 261094   Schleswig_Holstein       0.0        NaN         NaN       120.00
# 264041             Saarland       0.0      450.0        2.86        30.00
# 265287             Saarland       0.0        NaN        1.72        55.00
# 266925        Niedersachsen       0.0      670.0        4.11        75.00
#
#         geo_plz  picturecount  newlyConst  yearConstructed    scoutId  \
# 201        8058             7       False           1900.0  108372054
# 1377      66740             7       False           1956.0  108643336
# 2045      59174             1       False           1902.0  115454960
# 6911      84166             7       False              NaN  113267651
# 11130     67663             1       False              NaN  112047388
# ...         ...           ...         ...              ...        ...
# 254055    74889             7       False              NaN  107357543
# 261094    24855             7       False              NaN   63955810
# 264041    66740             8       False              NaN  107318389
# 265287    66333             0       False              NaN  105621115
# 266925    26725            18       False           1997.0  111374361
#
#              firingTypes       heatingType  hasKitchen  cellar  \
# 201                  gas   central_heating       False   False
# 1377    district_heating               NaN       False   False
# 2045                 gas   central_heating       False   False
# 6911                 oil   central_heating       False   False
# 11130                NaN               NaN       False   False
# ...                  ...               ...         ...     ...
# 254055               NaN               NaN        True   False
# 261094               gas   central_heating       False   False
# 264041               NaN  district_heating       False   False
# 265287               NaN     floor_heating       False   False
# 266925               gas   central_heating       False   False
#
#                                  condition                      street   lift  \
# 201                        fully_renovated  Franz-Mehring-Stra&szlig;e  False
# 1377                       fully_renovated              no_information  False
# 2045                             well_kept                 Bahnhofstr.  False
# 6911                                   NaN              no_information  False
# 11130                                  NaN              no_information  False
# ...                                    ...                         ...    ...
# 254055  first_time_use_after_refurbishment              no_information  False
# 261094                           well_kept             M&uuml;hlenstr.  False
# 264041                                 NaN              no_information  False
# 265287                                 NaN              no_information  False
# 266925                           well_kept              no_information  False
#
#           typeOfFlat  noRooms  floor  balcony  garden  baseRentRange  \
# 201        apartment      2.0    1.0    False   False              1
# 1377       apartment      1.0    NaN    False   False              1
# 2045             NaN      2.5    NaN    False   False              1
# 6911    ground_floor      1.0    NaN    False   False              1
# 11130      apartment      1.0    NaN    False   False              1
# ...              ...      ...    ...      ...     ...            ...
# 254055  ground_floor      2.0    0.0    False   False              1
# 261094  ground_floor      5.0    NaN    False   False              1
# 264041  ground_floor      1.0    NaN    False   False              1
# 265287   roof_storey      1.0    NaN    False   False              1
# 266925     apartment      3.0    NaN     True   False              1
#
#         noRoomsRange  livingSpaceRange  yearConstructedRange  \
# 201                2                 2                   1.0
# 1377               1                 1                   2.0
# 2045               2                 3                   1.0
# 6911               1                 2                   NaN
# 11130              1                 1                   NaN
# ...              ...               ...                   ...
# 254055             2                 1                   NaN
# 261094             5                 5                   NaN
# 264041             1                 1                   NaN
# 265287             1                 2                   NaN
# 266925             3                 3                   5.0
#
#                                 regio2        regio3  \
# 201                            Zwickau  Nordvorstadt
# 1377                   Saarlouis_Kreis     Saarlouis
# 2045                        Unna_Kreis         Kamen
# 6911                    Landshut_Kreis      Adlkofen
# 11130                   Kaiserslautern    Innenstadt
# ...                                ...           ...
# 254055              Rhein_Neckar_Kreis      Sinsheim
# 261094       Schleswig_Flensburg_Kreis  Bollingstedt
# 264041                 Saarlouis_Kreis     Saarlouis
# 265287  Stadtverband_Saarbrücken_Kreis    Völklingen
# 266925                           Emden  Stadtzentrum
#
#                                               description   date
# 201     Sie sind ein fleißiger und handwerklich begabt...  May19
# 1377    Dieses Appartement besteht aus einem Wohn- Sch...  Feb20
# 2045    Das charmante Fachwerkhaus verfügt im Erdgesch...  Feb20
# 6911    Dieses Teilmöblierte Appartement liegt in ruhi...  Oct19
# 11130   Wir finden für Sie 1 Zimmer - Apartments im Un...  Oct19
# ...                                                   ...    ...
# 254055  *WICHTIGE INFO*:\nDie Raumhöhe liegt unter 2,3...  Sep18
# 261094                  Wohnung langfristig zu vermieten.  Oct19
# 264041  Ein Wohn- Schlafraum, eine EBK mit Kühlschrank...  Sep18
# 265287  PREIS AUF ANFRAGE\n\nSchöne 2ZKB Wohnung in Vö...  Sep18
# 266925  Diese großzügige Wohnung (1. Obergeschoss) lie...  May19
#
# [89 rows x 30 columns]

# %%
base_rent = df_trim['baseRent']
base_rent.replace(to_replace = 0,  method='bfill', inplace=True)

# %%
# check that no zeroes remain in base rent
df_trim[df_trim['baseRent'] == 0.0]
# Out:
# Empty DataFrame
# Columns: [regio1, baseRent, totalRent, pricetrend, livingSpace, geo_plz, picturecount, newlyConst, yearConstructed, scoutId, firingTypes, heatingType, hasKitchen, cellar, condition, street, lift, typeOfFlat, noRooms, floor, balcony, garden, baseRentRange, noRoomsRange, livingSpaceRange, yearConstructedRange, regio2, regio3, description, date]
# Index: []

# %%
# view remaining low rents
df_trim[df_trim['totalRent'] < 100.0]
# Out:
#                      regio1  baseRent  totalRent  pricetrend  livingSpace  \
# 6601         Sachsen_Anhalt      35.0       35.0        1.64          0.0
# 9332                Sachsen     250.0       75.0        0.00         50.0
# 11922               Sachsen      25.0       25.0        0.19         12.5
# 18360                Bayern      50.0       50.0        4.70         20.0
# 19381     Baden_Württemberg      50.0       50.0        4.39          3.0
# ...                     ...       ...        ...         ...          ...
# 241782        Niedersachsen    1111.0        1.0        3.70        101.0
# 243082              Sachsen     459.0        1.0        1.89         70.6
# 249754  Nordrhein_Westfalen     960.0        1.3        3.92         91.0
# 261708              Sachsen      99.0       97.0        5.36         20.0
# 263216              Sachsen     250.0        3.0        0.00         46.0
#
#         geo_plz  picturecount  newlyConst  yearConstructed    scoutId  \
# 6601       6217             1       False              NaN  100870699
# 9332       9131             5       False           1915.0  109939615
# 11922      9113             6       False           1920.0   97569416
# 18360     84453             0        True           2019.0  108750293
# 19381     75177             1       False           1954.0  108001105
# ...         ...           ...         ...              ...        ...
# 241782    21423            11        True           2019.0  111139920
# 243082     9111             1       False              NaN  107330418
# 249754    53819             5        True           2019.0  112892262
# 261708     4315            22       False           1899.0   93855770
# 263216     8359             5       False           1950.0  110620002
#
#              firingTypes       heatingType  hasKitchen  cellar  \
# 6601                 NaN               NaN       False   False
# 9332                 NaN               NaN       False    True
# 11922                NaN   central_heating       False   False
# 18360   district_heating  district_heating       False   False
# 19381                oil               NaN       False    True
# ...                  ...               ...         ...     ...
# 241782               gas   central_heating        True   False
# 243082               NaN               NaN       False    True
# 249754               NaN     floor_heating       False   False
# 261708               NaN   central_heating       False   False
# 263216               gas               NaN       False    True
#
#                                  condition                 street   lift  \
# 6601                             well_kept         no_information  False
# 9332                                   NaN         no_information  False
# 11922                       mint_condition       Bergstra&szlig;e  False
# 18360                                  NaN  Waidbruckstra&szlig;e  False
# 19381                                  NaN       Bl&uuml;cherstr.  False
# ...                                    ...                    ...    ...
# 241782                      first_time_use            Brahmsallee   True
# 243082  first_time_use_after_refurbishment     Elisenstra&szlig;e  False
# 249754                      first_time_use         no_information  False
# 261708                      first_time_use         no_information  False
# 263216                                 NaN         no_information  False
#
#           typeOfFlat  noRooms  floor  balcony  garden  baseRentRange  \
# 6601           other      1.0    NaN    False   False              1
# 9332     roof_storey      2.0    NaN    False   False              1
# 11922            NaN      1.0    NaN    False   False              1
# 18360          other      1.0    NaN    False   False              1
# 19381          other      1.0   -1.0    False   False              1
# ...              ...      ...    ...      ...     ...            ...
# 241782     apartment      3.0    1.0     True   False              7
# 243082     apartment      3.0    2.0     True   False              3
# 249754         other      2.0    1.0    False   False              6
# 261708     apartment      1.0    3.0    False   False              1
# 263216  ground_floor      2.0    NaN    False   False              1
#
#         noRoomsRange  livingSpaceRange  yearConstructedRange  \
# 6601               1                 1                   NaN
# 9332               2                 2                   1.0
# 11922              1                 1                   1.0
# 18360              1                 1                   9.0
# 19381              1                 1                   2.0
# ...              ...               ...                   ...
# 241782             3                 5                   9.0
# 243082             3                 3                   NaN
# 249754             2                 4                   9.0
# 261708             1                 1                   1.0
# 263216             2                 2                   1.0
#
#                        regio2                   regio3  \
# 6601               Saalekreis                Merseburg
# 9332                 Chemnitz                Ebersdorf
# 11922                Chemnitz           Schloßchemnitz
# 18360   Mühldorf_am_Inn_Kreis          Mühldorf_am_Inn
# 19381               Pforzheim                Nordstadt
# ...                       ...                      ...
# 241782          Harburg_Kreis              Winsen_Luhe
# 243082               Chemnitz                  Zentrum
# 249754       Rhein_Sieg_Kreis   Neunkirchen_Seelscheid
# 261708                Leipzig             Volkmarsdorf
# 263216        Erzgebirgskreis  Breitenbrunn/Erzgebirge
#
#                                               description   date
# 6601                                                  NaN  May19
# 9332    Der Zuschnitt der Wohnung ist großzügig und ze...  Oct19
# 11922   Das Objekt ist ein Kulturdenkmal gem. § 2\nSäc...  Oct19
# 18360   Große Tiefgarage in einem Neubau.\n10 Stellplä...  May19
# 19381   Miete mtl. 50,-€\nKaution : 150,-€\n\nPreis is...  May19
# ...                                                   ...    ...
# 241782                                                NaN  May19
# 243082  Das Stadthaus im Gewand der Gründerzeit in der...  May19
# 249754  Die Untergeschosswohnung befindet sich in eine...  Oct19
# 261708  Hallo, \n\nhier könnt ihr entweder Zimmer so g...  Sep18
# 263216  Vermietet wird hier eine schöne und ruhig gele...  May19
#
# [78 rows x 30 columns]

# %% [markdown]
# There are still quite a few rows with rents that seem implausibly low. Because it's too many for me to check individually but represents a small percentage of the data, I opted to drop these rows.

# %%
# drop rows where total rent is less than 100
df_trim = df_trim.drop(df_trim[df_trim.totalRent < 100.0].index)

# %%
# check that drop worked
df_trim[df_trim['totalRent'] < 100.0]
# Out:
# Empty DataFrame
# Columns: [regio1, baseRent, totalRent, pricetrend, livingSpace, geo_plz, picturecount, newlyConst, yearConstructed, scoutId, firingTypes, heatingType, hasKitchen, cellar, condition, street, lift, typeOfFlat, noRooms, floor, balcony, garden, baseRentRange, noRoomsRange, livingSpaceRange, yearConstructedRange, regio2, regio3, description, date]
# Index: []

# %%
df_trim['totalRent'].describe()
# Out:
# count    228223.000000
# mean        814.815558
# std         562.467754
# min         100.000000
# 25%         470.000000
# 50%         650.000000
# 75%         985.000000
# max       26500.000000
# Name: totalRent, dtype: float64

# %% [markdown]
# The mean rent has decreased by about 100 Euro.
# Now I'll follow the same procedure for checking out high and low baseRent values.

# %% [markdown]
# ## 04b. Base rent anomalies

# %%
highBaseRent = df_trim[df_trim['baseRent'] > 10000.0]

# %%
# copy to clipboard so I can view in Excel
highBaseRent.to_clipboard()

# %%
df_trim.loc[df_trim['regio1'] == 'Saarland', 'baseRent'].median()
# Out:
# 530.0

# %%
df_trim.loc[df_trim['regio1'] == 'Baden_Württemberg', 'baseRent'].median()
# Out:
# 850.0

# %%
df_trim.loc[df_trim['regio1'] == 'Bayern', 'baseRent'].median()
# Out:
# 850.0

# %%
df_trim.loc[df_trim['regio1'] == 'Nordrhein_Westfalen', 'baseRent'].median()
# Out:
# 490.0

# %%
df_trim.loc[df_trim['regio1'] == 'Sachsen_Anhalt', 'baseRent'].median()
# Out:
# 325.0

# %%
# replace incorrect baseRent values
df_trim = df_trim.replace({'baseRent': {120000: 1200, 20100: 2010, 39200: 392, 30990: 310, 120000: 400, 9999999: 530, 1234567: 850, 10440: 490, 1000000: 325}})

# %%
df_trim['baseRent'].describe()
# Out:
# count    268772.000000
# mean        647.661063
# std         505.609452
# min           1.000000
# 25%         338.000000
# 50%         490.000000
# 75%         799.000000
# max       20000.000000
# Name: baseRent, dtype: float64

# %% [markdown]
# I spotted a few construction years that seemed too far in the future for an advertised unit, so let's check out everything after 2022.

# %% [markdown]
# ## 04c. Year constructed anomalies

# %%
df_trim[df_trim['yearConstructed'] > 2022.0]
# Out:
#                    regio1  baseRent  totalRent  pricetrend  livingSpace  \
# 40265              Berlin     470.0      590.0        6.29        31.00
# 54595              Hessen    2945.0     3385.0        4.48       156.13
# 87221   Baden_Württemberg    1175.0     1475.0        3.96       130.64
# 182121             Hessen    1620.0     1910.0        4.48       102.44
# 240346             Hessen    1435.0     1690.0        4.48        91.07
#
#         geo_plz  picturecount  newlyConst  yearConstructed    scoutId  \
# 40265     12487             9        True           2029.0  114977577
# 54595     60594            14        True           2026.0  113807419
# 87221     76437            10        True           2090.0  110659704
# 182121    60594            17        True           2026.0  113807326
# 240346    60594            10        True           2026.0  113807369
#
#              firingTypes       heatingType  hasKitchen  cellar  \
# 40265                NaN  district_heating        True    True
# 54595                NaN     floor_heating        True   False
# 87221   district_heating  district_heating       False    True
# 182121               NaN     floor_heating        True   False
# 240346               NaN     floor_heating        True   False
#
#              condition                       street  lift    typeOfFlat  \
# 40265   first_time_use     Gro&szlig;-Berliner Damm  True     apartment
# 54595   mint_condition  Gerberm&uuml;hlstra&szlig;e  True     apartment
# 87221   mint_condition               no_information  True  ground_floor
# 182121  mint_condition  Gerberm&uuml;hlstra&szlig;e  True     apartment
# 240346  mint_condition  Gerberm&uuml;hlstra&szlig;e  True     apartment
#
#         noRooms  floor  balcony  garden  baseRentRange  noRoomsRange  \
# 40265       1.0    2.0    False   False              3             1
# 54595       4.0    6.0    False   False              9             4
# 87221       4.0    NaN     True   False              7             4
# 182121      3.0    4.0    False   False              8             3
# 240346      3.0    4.0    False   False              7             3
#
#         livingSpaceRange  yearConstructedRange             regio2  \
# 40265                  1                   9.0             Berlin
# 54595                  7                   9.0  Frankfurt_am_Main
# 87221                  6                   9.0      Rastatt_Kreis
# 182121                 5                   9.0  Frankfurt_am_Main
# 240346                 4                   9.0  Frankfurt_am_Main
#
#                       regio3  \
# 40265   Johannisthal_Treptow
# 54595     Sachsenhausen_Nord
# 87221                Rastatt
# 182121    Sachsenhausen_Nord
# 240346    Sachsenhausen_Nord
#
#                                               description   date
# 40265   Das Objekt ist ein Neubau und befindet sich im...  Feb20
# 54595   Die hier angebotene exklusive 4-Zimmer-Wohnung...  Oct19
# 87221   In einem hochwertigen und sehr modernen Gebäud...  May19
# 182121  Die hier angebotene 3-Zimmer-Wohnung befindet ...  Oct19
# 240346  Die hier angebotene 3-Zimmer-Wohnung befindet ...  Oct19

# %%
# replace with correct years inferred from scraping date and description.
df_trim = df_trim.replace ({'yearConstructed':{2029.0: 2020, 2026.0: 2019, 2090: 2019}})

# %%
df_trim[df_trim['yearConstructed'] > 2022.0]
# Out:
# Empty DataFrame
# Columns: [regio1, baseRent, totalRent, pricetrend, livingSpace, geo_plz, picturecount, newlyConst, yearConstructed, scoutId, firingTypes, heatingType, hasKitchen, cellar, condition, street, lift, typeOfFlat, noRooms, floor, balcony, garden, baseRentRange, noRoomsRange, livingSpaceRange, yearConstructedRange, regio2, regio3, description, date]
# Index: []

# %% [markdown]
# Following the same procedure for early years, I noticed a string of buildings constructed in 1111. This appears to be a placeholder, so I'll replace it with the column mean.

# %%
df_trim[df_trim['yearConstructed'] == 1111.0]
# Out:
#                      regio1  baseRent  totalRent  pricetrend  livingSpace  \
# 2152    Nordrhein_Westfalen    415.00     580.00        3.45        59.14
# 2541                Sachsen    290.00     392.50        3.00        49.50
# 7604                Sachsen    310.12     378.12        3.87        50.84
# 8817    Nordrhein_Westfalen    555.00     725.00        4.66        66.92
# 11923               Sachsen    433.00     568.00        1.72        58.58
# ...                     ...       ...        ...         ...          ...
# 255950              Hamburg    681.23     873.23        4.45        61.93
# 258549   Schleswig_Holstein    210.00     313.00        3.27        24.88
# 261781              Sachsen    283.01     355.01        4.33        41.68
# 265442               Berlin    365.87     522.87        6.82        51.97
# 267018              Sachsen    380.00     527.00        4.33        62.60
#
#         geo_plz  picturecount  newlyConst  yearConstructed    scoutId  \
# 2152      47229             7       False           1111.0  115538262
# 2541       4249             7       False           1111.0  115267331
# 7604       4277             7       False           1111.0  115555925
# 8817      44803             4       False           1111.0  115627128
# 11923      1157             8       False           1111.0  114929482
# ...         ...           ...         ...              ...        ...
# 255950    21029             9       False           1111.0  115378043
# 258549    24116             4       False           1111.0  115704742
# 261781     4317             7       False           1111.0  115687129
# 265442    13403             8       False           1111.0  115590265
# 267018     4317             8       False           1111.0  115433308
#
#        firingTypes                     heatingType  hasKitchen  cellar  \
# 2152           NaN                 central_heating       False    True
# 2541           NaN                 central_heating       False    True
# 7604           NaN  self_contained_central_heating       False    True
# 8817           NaN                 central_heating       False    True
# 11923          NaN                 central_heating       False    True
# ...            ...                             ...         ...     ...
# 255950         NaN                 central_heating       False    True
# 258549         NaN                 central_heating       False    True
# 261781         NaN                 central_heating       False    True
# 265442         NaN                 central_heating       False    True
# 267018         NaN                 central_heating        True    True
#
#        condition                       street   lift    typeOfFlat  noRooms  \
# 2152         NaN                 Henschelstr.  False     apartment      3.0
# 2541         NaN  Giordano-Bruno-Stra&szlig;e  False   roof_storey      1.0
# 7604         NaN        Burgst&auml;dter Str.  False     apartment      2.0
# 8817         NaN           Andreas-Hofer-Str.  False     apartment      2.0
# 11923        NaN              Grillparzerstr.  False     apartment      2.0
# ...          ...                          ...    ...           ...      ...
# 255950       NaN               Vierlandenstr.  False     apartment      2.5
# 258549       NaN                     Westring   True  ground_floor      1.0
# 261781       NaN             Reichpietschstr.  False  ground_floor      1.0
# 265442       NaN                   Waldowstr.  False     apartment      2.0
# 267018       NaN              Oststra&szlig;e  False     apartment      2.0
#
#         floor  balcony  garden  baseRentRange  noRoomsRange  livingSpaceRange  \
# 2152      1.0    False   False              3             3                 2
# 2541      NaN     True   False              1             1                 2
# 7604      2.0     True   False              2             2                 2
# 8817      1.0     True   False              4             2                 3
# 11923     1.0     True   False              3             2                 2
# ...       ...      ...     ...            ...           ...               ...
# 255950    1.0    False   False              5             2                 3
# 258549    NaN    False   False              1             1                 1
# 261781    NaN    False   False              1             1                 2
# 265442    2.0     True   False              2             2                 2
# 267018    3.0     True   False              2             2                 3
#
#         yearConstructedRange    regio2                       regio3  \
# 2152                     1.0  Duisburg                 Friemersheim
# 2541                     1.0   Leipzig                Großzschocher
# 7604                     1.0   Leipzig                    Connewitz
# 8817                     1.0    Bochum                  Altenbochum
# 11923                    1.0   Dresden                        Cotta
# ...                      ...       ...                          ...
# 255950                   1.0   Hamburg                    Bergedorf
# 258549                   1.0      Kiel                Schreventeich
# 261781                   1.0   Leipzig            Reudnitz_Thonberg
# 265442                   1.0    Berlin  Reinickendorf_Reinickendorf
# 267018                   1.0   Leipzig            Reudnitz_Thonberg
#
#                                               description   date
# 2152    - Modernisiertes Badezimmer\n - Bad mit Fenste...  Feb20
# 2541    Gerne können Sie einen Besichtigungstermin mit...  Feb20
# 7604    Gerne können Sie einen Besichtigungstermin mit...  Feb20
# 8817                                                  NaN  Feb20
# 11923   Einen individuellen Besichtigungstermin verein...  Feb20
# ...                                                   ...    ...
# 255950  + Genießen Sie Ihre Bewegungsfreiheit und Komf...  Feb20
# 258549  Schöne und günstige 1-Zimmer-Studentenwohnung ...  Feb20
# 261781  Gerne können Sie einen Besichtigungstermin mit...  Feb20
# 265442  Eine helle Wohnung mit Balkon und gefliestem W...  Feb20
# 267018  Genießen Sie Ihr neues Kocherlebnis in einer i...  Feb20
#
# [87 rows x 30 columns]

# %%
year_col = df_trim['yearConstructed']
year_col.replace(to_replace = 1111.0, value = year_col.mean(), inplace=True)

# %%
# check that no unusual years remain
df_trim[df_trim['yearConstructed'] == 1111.0]
# Out:
# Empty DataFrame
# Columns: [regio1, baseRent, totalRent, pricetrend, livingSpace, geo_plz, picturecount, newlyConst, yearConstructed, scoutId, firingTypes, heatingType, hasKitchen, cellar, condition, street, lift, typeOfFlat, noRooms, floor, balcony, garden, baseRentRange, noRoomsRange, livingSpaceRange, yearConstructedRange, regio2, regio3, description, date]
# Index: []

# %%
# check out the minimum year. It's an old church tower, so 1000 seems plausible.
df_trim[df_trim['yearConstructed'] == 1000.0]
# Out:
#                 regio1  baseRent  totalRent  pricetrend  livingSpace  geo_plz  \
# 124633  Sachsen_Anhalt     500.0      580.0        2.13         78.0     6420
#
#         picturecount  newlyConst  yearConstructed   scoutId  firingTypes  \
# 124633            16       False           1000.0  68781039  electricity
#
#                  heatingType  hasKitchen  cellar       condition    street  \
# 124633  night_storage_heater        True   False  mint_condition  Dorfstr.
#
#          lift typeOfFlat  noRooms  floor  balcony  garden  baseRentRange  \
# 124633  False  apartment      3.0    NaN    False   False              3
#
#         noRoomsRange  livingSpaceRange  yearConstructedRange         regio2  \
# 124633             3                 3                   1.0  Salzlandkreis
#
#          regio3                                        description   date
# 124633  Könnern  Die Wohnung befindet sich in einem ehemaligen ...  Sep18

# %%
df_trim['yearConstructed'].describe()
# Out:
# count    211765.000000
# mean       1966.751823
# std          43.675181
# min        1000.000000
# 25%        1950.000000
# 50%        1973.000000
# 75%        1996.000000
# max        2022.000000
# Name: yearConstructed, dtype: float64

# %% [markdown]
# ## 04d. Living space (size) anomalies

# %% [markdown]
# Next, I'll check out suspicious values in livingSpace. 600 square meters is quite large for an apartment, so let's look at anything bigger than that.

# %%
df_trim[df_trim['livingSpace'] > 599]
# Out:
#                      regio1  baseRent  totalRent  pricetrend  livingSpace  \
# 12420                Bremen    520.00     720.00        2.74       649.00
# 14123                Hessen  12000.00   13400.00        5.13       600.00
# 50683               Sachsen    825.00        NaN        0.72      1717.74
# 51540           Brandenburg    504.00     650.00        4.33      8684.00
# 92451                Bayern    800.00        NaN        3.58      2257.88
# 97475                Bayern    340.00     454.69        5.96       600.00
# 151184               Bayern   1200.00    1400.00        6.09     66100.00
# 170816               Hessen  19329.00   20588.00        5.21       601.85
# 172399              Sachsen    200.00     260.00        1.24      4340.00
# 175397       Sachsen_Anhalt    679.00     369.00        4.61    111111.00
# 202205  Nordrhein_Westfalen    519.00        NaN        3.29      7008.00
# 215900              Sachsen    245.00        NaN        1.44      2782.00
# 222457  Nordrhein_Westfalen    283.14        NaN        5.97      2420.00
# 223187               Hessen   1385.00    1641.50        6.17     10259.00
# 227775   Schleswig_Holstein    539.00     541.50        3.84      1000.00
# 229248  Nordrhein_Westfalen    200.00        NaN        3.57      4947.00
# 243713  Nordrhein_Westfalen    400.00        NaN        3.61     14000.00
#
#         geo_plz  picturecount  newlyConst  yearConstructed    scoutId  \
# 12420     28357            10       False              NaN  115371332
# 14123     60322             2       False           1900.0   98567656
# 50683      9112            11       False           1911.0  114935600
# 51540     16225             8       False           1996.0  109860941
# 92451     90518            30        True           2019.0  110383735
# 97475     94315             7       False           2016.0   90422924
# 151184    81737            23       False           1987.0  109350573
# 170816    60322            11       False              NaN  114421851
# 172399     8529             5       False              NaN  111349875
# 175397    39624             0       False              NaN  113363197
# 202205    33104            11       False           1964.0  112281127
# 215900     2782             9       False           1923.0  111330060
# 222457    48159             3       False           1974.0  113860387
# 223187    60435            11       False           2016.0  109754861
# 227775    23843             1        True           2020.0  115168420
# 229248    47137             2       False           1988.0   63845567
# 243713    45133            12       False           1984.0  111426318
#
#               firingTypes                     heatingType  hasKitchen  cellar  \
# 12420                 NaN                district_heating       False    True
# 14123                 gas  self_contained_central_heating       False   False
# 50683                 NaN                             NaN       False    True
# 51540                 gas                 central_heating        True    True
# 92451                 gas                             NaN       False   False
# 97475                 gas                 central_heating        True   False
# 151184                oil                 central_heating       False    True
# 170816                gas                     gas_heating       False   False
# 172399                gas                 central_heating       False    True
# 175397                NaN                             NaN       False   False
# 202205                oil                     oil_heating        True   False
# 215900                gas                 central_heating       False    True
# 222457  natural_gas_light                 central_heating        True    True
# 223187   district_heating                district_heating        True    True
# 227775                gas                     gas_heating        True    True
# 229248                gas                     gas_heating       False   False
# 243713        electricity                   floor_heating       False    True
#
#                                  condition                             street  \
# 12420   first_time_use_after_refurbishment                     no_information
# 14123                           negotiable           Auf der K&ouml;rnerwiese
# 50683   first_time_use_after_refurbishment                 Reichsstra&szlig;e
# 51540                           modernized            Danckelmannstra&szlig;e
# 92451                                  NaN                     no_information
# 97475                      fully_renovated                           Enggasse
# 151184                           well_kept           Neubiberger Stra&szlig;e
# 170816  first_time_use_after_refurbishment                   Hochstra&szlig;e
# 172399                           well_kept                     no_information
# 175397                                 NaN  G&uuml;ssefelder Dorfstra&szlig;e
# 202205                           well_kept               Lahrkampstra&szlig;e
# 215900                     fully_renovated                           Marxstr.
# 222457                           well_kept                Killingstra&szlig;e
# 223187                      mint_condition                       Am Klarapfel
# 227775                      first_time_use                Bahnhofstra&szlig;e
# 229248                           well_kept                 L&ouml;sorter Str.
# 243713                           well_kept                     Weg zur Platte
#
#          lift    typeOfFlat  noRooms  floor  balcony  garden  baseRentRange  \
# 12420   False     apartment      3.0    2.0     True   False              4
# 14123    True    maisonette     15.0    4.0     True   False              9
# 50683    True     apartment      5.0    NaN     True   False              1
# 51540   False           NaN      3.0    4.0    False    True              4
# 92451   False           NaN     75.5    NaN    False   False              5
# 97475   False           NaN     23.0    NaN    False   False              2
# 151184  False   roof_storey      2.0    2.0    False    True              7
# 170816   True     penthouse      6.0    7.0     True   False              9
# 172399  False     apartment      2.0    1.0    False   False              1
# 175397  False     apartment      3.0    NaN    False   False              5
# 202205  False     apartment      3.0    2.0     True   False              4
# 215900  False  ground_floor      3.0    0.0    False    True              1
# 222457   True     apartment      1.0    7.0     True   False              1
# 223187   True     apartment      3.0    1.0     True    True              7
# 227775   True         other     15.0    4.0     True   False              4
# 229248  False  ground_floor      2.0    NaN     True   False              1
# 243713  False     apartment      3.5    1.0     True   False              9
#
#         noRoomsRange  livingSpaceRange  yearConstructedRange  \
# 12420              3                 7                   NaN
# 14123              5                 7                   1.0
# 50683              5                 7                   1.0
# 51540              3                 7                   5.0
# 92451              5                 7                   9.0
# 97475              5                 7                   9.0
# 151184             2                 7                   4.0
# 170816             5                 7                   NaN
# 172399             2                 7                   NaN
# 175397             3                 7                   NaN
# 202205             3                 7                   2.0
# 215900             3                 7                   1.0
# 222457             1                 7                   3.0
# 223187             3                 7                   9.0
# 227775             5                 7                   9.0
# 229248             2                 7                   4.0
# 243713             3                 7                   4.0
#
#                         regio2                regio3  \
# 12420                   Bremen         Lehesterdeich
# 14123        Frankfurt_am_Main          Westend_Nord
# 50683                 Chemnitz               Kaßberg
# 51540             Barnim_Kreis            Eberswalde
# 92451    Nürnberger_Land_Kreis  Altdorf_bei_Nürnberg
# 97475                Straubing             Kernstadt
# 151184                 München               Perlach
# 170816       Frankfurt_am_Main            Innenstadt
# 172399                  Plauen       Reusa_mit_Sorga
# 175397  Altmarkkreis_Salzwedel             Güssefeld
# 202205         Paderborn_Kreis             Paderborn
# 215900           Görlitz_Kreis       Seifhennersdorf
# 222457                 Münster       Kinderhaus_West
# 223187       Frankfurt_am_Main          Preungesheim
# 227775          Stormarn_Kreis          Bad_Oldesloe
# 229248                Duisburg       Mittelmeiderich
# 243713                   Essen              Bredeney
#
#                                               description   date
# 12420   Die angebotene Wohnung  befindet sich im 2.Obe...  Feb20
# 14123   Über die hellen, mit Granit verkleideten Trepp...  Oct19
# 50683   Diese großzügig geschnittene Villa überzeugt d...  Feb20
# 51540   Das Wohnhaus wurde im Jahre 1996 neu errichtet...  Oct19
# 92451   *****Bitte beachten Sie, der angegebene Preis ...  May19
# 97475   Kernsanierte Häuser mit insgesamt 12 Wohnungen...  Oct19
# 151184  + kleines gepflegtes Mehrfamilienhaus\n\n+ 2-Z...  May19
# 170816  Ausgestattet mit hochwertigem Eichen-Parkett, ...  Feb20
# 172399  Ihre neue Wohnung befindet sich in einem ruhig...  May19
# 175397                                                NaN  Oct19
# 202205  Sämtliche Erdgeschoss-Wohnungen wurden mit Jal...  Oct19
# 215900  Diese helle sonnige Wohnung eignet sich auf Gr...  May19
# 222457  Das Zimmer befindet sich in einer Wohnung im 7...  Oct19
# 223187  Hell und luftig präsentiert sich der fünfgesch...  May19
# 227775  Das TORHAUS steht hochmodern und selbstbewusst...  Feb20
# 229248  Es handelt sich um einen Altbau , der im Jahre...  May19
# 243713  Die Wohnung liegt im 1. Obergeschoss in einem ...  May19

# %%
df_trim.loc[df_trim['noRoomsRange'] == 5, 'livingSpace'].median()
# Out:
# 144.0

# %%
df_trim.loc[df_trim['noRoomsRange'] == 3, 'livingSpace'].median()
# Out:
# 77.12

# %%
df_trim.loc[df_trim['noRoomsRange'] == 2, 'livingSpace'].median()
# Out:
# 58.01

# %%
df_trim.loc[df_trim['noRoomsRange'] == 1, 'livingSpace'].median()
# Out:
# 35.0

# %% [markdown]
# To deal with the suspicious values, I'll replace 8 with the mean for the given noRoomsRange, correct one value that included the correct value in the description, and correct 9 values where livingSpace was swapped with noRooms.

# %%
df_trim = df_trim.replace({'livingSpace': {2257.88: 144.0, 1000.00: 144.0, 8684.00: 77.12, 111111.00: 77.12, 2782.00: 77.12, 7008.00: 77.12, 10259.00: 77.12, 14000.00: 77.12, 4340.00: 58.01, 4947.00: 58.01, 2420.00: 35.0, 66100.0: 166.0, 144: 52, 600: 60, 2: 45, 1: 75, 446: 45, 3: 99}})

# %% [markdown]
# Now, let's see the rows where livingSpace is listed as zero. That seems wrong.

# %%
df_trim[df_trim['livingSpace'] == 0.0]
# Out:
#                         regio1  baseRent  totalRent  pricetrend  livingSpace  \
# 3444            Sachsen_Anhalt    620.00      890.0        1.98          0.0
# 11127            Niedersachsen    775.00      865.0        3.75          0.0
# 15014                   Hessen    110.00      110.0        6.04          0.0
# 17278                  Sachsen    160.00        NaN        0.00          0.0
# 18433                  Sachsen    357.74        NaN        0.00          0.0
# ...                        ...       ...        ...         ...          ...
# 247111       Baden_Württemberg    450.00      490.0        4.07          0.0
# 248599  Mecklenburg_Vorpommern    325.00      465.0        1.13          0.0
# 254055       Baden_Württemberg   1018.15      470.0        4.29          0.0
# 266160       Baden_Württemberg    450.00      480.0        4.24          0.0
# 267604       Baden_Württemberg    450.00      490.0        4.52          0.0
#
#         geo_plz  picturecount  newlyConst  yearConstructed    scoutId  \
# 3444       6847            10       False           1985.0  113671451
# 11127     30459             7       False              NaN  106780303
# 15014     60326             1       False              NaN  111383274
# 17278      9599             5       False           1987.0  103331711
# 18433      9130             1       False           1920.0  104445035
# ...         ...           ...         ...              ...        ...
# 247111    76137             2       False              NaN  113593869
# 248599    17192            18       False           1888.0  109978237
# 254055    74889             7       False              NaN  107357543
# 266160    76137             7       False           1900.0  113744252
# 267604    76137             2        True           2018.0  106511951
#
#              firingTypes                     heatingType  hasKitchen  cellar  \
# 3444                 NaN                             NaN       False   False
# 11127                gas  self_contained_central_heating       False    True
# 15014                NaN                             NaN       False   False
# 17278   district_heating                district_heating        True    True
# 18433                gas                 central_heating       False   False
# ...                  ...                             ...         ...     ...
# 247111               gas                 central_heating       False   False
# 248599               gas                 central_heating       False   False
# 254055               NaN                             NaN        True   False
# 266160               gas                 central_heating       False   False
# 267604               gas                 central_heating       False   False
#
#                                  condition                     street   lift  \
# 3444                                   NaN                Ellerbreite  False
# 11127                            well_kept     Barsingh&auml;userstr.  False
# 15014                                  NaN          Helmut Walcha Str  False
# 17278                                  NaN       Paul-M&uuml;ller-Str  False
# 18433                                  NaN  Stra&szlig;e der Nationen  False
# ...                                    ...                        ...    ...
# 247111                      mint_condition             no_information  False
# 248599                           well_kept             Teterower Str.  False
# 254055  first_time_use_after_refurbishment             no_information  False
# 266160                                 NaN             no_information  False
# 267604                      first_time_use                Vorholzstr.  False
#
#           typeOfFlat  noRooms  floor  balcony  garden  baseRentRange  \
# 3444             NaN      5.0    5.0     True   False              5
# 11127          other      2.0    NaN     True    True              5
# 15014            NaN      1.0    NaN    False   False              1
# 17278      apartment      1.0    5.0    False   False              1
# 18433            NaN      2.0    NaN    False   False              1
# ...              ...      ...    ...      ...     ...            ...
# 247111  ground_floor      1.0    NaN    False   False              3
# 248599     apartment      2.0    1.0    False   False              2
# 254055  ground_floor      2.0    0.0    False   False              1
# 266160  ground_floor      1.0    1.0    False   False              3
# 267604  ground_floor      1.0    NaN    False   False              3
#
#         noRoomsRange  livingSpaceRange  yearConstructedRange  \
# 3444               5                 1                   4.0
# 11127              2                 1                   NaN
# 15014              1                 1                   NaN
# 17278              1                 1                   4.0
# 18433              2                 1                   1.0
# ...              ...               ...                   ...
# 247111             1                 1                   NaN
# 248599             2                 1                   1.0
# 254055             2                 1                   NaN
# 266160             1                 1                   1.0
# 267604             1                 1                   9.0
#
#                      regio2          regio3  \
# 3444          Dessau_Roßlau       Zoberberg
# 11127              Hannover  Oberricklingen
# 15014     Frankfurt_am_Main   Gallusviertel
# 17278   Mittelsachsen_Kreis        Freiberg
# 18433              Chemnitz  Schloßchemnitz
# ...                     ...             ...
# 247111            Karlsruhe    Südweststadt
# 248599         Müritz_Kreis    Waren_Müritz
# 254055   Rhein_Neckar_Kreis        Sinsheim
# 266160            Karlsruhe        Südstadt
# 267604            Karlsruhe    Südweststadt
#
#                                               description   date
# 3444                                                  NaN  Oct19
# 11127   Diese moderne 2-Zimmer-Design-Wohnung befindet...  Sep18
# 15014   Es handelt sich um einen TG Stellplatz, der si...  May19
# 17278                                                 NaN  May19
# 18433   Dieses schöne Haus aus der Gründerzeit bestich...  May19
# ...                                                   ...    ...
# 247111  Helle 1 Zimmer-Wohnung in der Karlsruher Südwe...  Oct19
# 248599  Solides und ruhiges Mehrfamilienhaus in Randla...  May19
# 254055  *WICHTIGE INFO*:\nDie Raumhöhe liegt unter 2,3...  Sep18
# 266160  Das schöne 1-Zimmer-Apartment verfügt über ein...  Oct19
# 267604  Helle 1 Zimmer-Wohnung in der Karlsruher Südwe...  Sep18
#
# [71 rows x 30 columns]

# %%
# replace zeroes in livingSpace with NaN
df_trim['livingSpace'].replace(0, np.nan, inplace=True)

# %%
df_trim.describe()
# Out:
#             baseRent      totalRent     pricetrend    livingSpace  \
# count  268772.000000  228223.000000  266940.000000  268701.000000
# mean      647.661063     814.815558       3.389086      73.461159
# std       505.609452     562.467754       1.964909      32.158670
# min         1.000000     100.000000     -12.330000       5.000000
# 25%       338.000000     470.000000       2.000000      54.000000
# 50%       490.000000     650.000000       3.390000      67.280000
# 75%       799.000000     985.000000       4.570000      86.910000
# max     20000.000000   26500.000000      14.920000    1717.740000
#
#              geo_plz   picturecount  yearConstructed       scoutId  \
# count  268772.000000  268772.000000    211765.000000  2.687720e+05
# mean    37281.874834       9.792668      1966.751823  1.069701e+08
# std     27797.004173       6.408047        43.675181  1.250013e+07
# min       852.000000       0.000000      1000.000000  2.887174e+07
# 25%      9128.000000       6.000000      1950.000000  1.066912e+08
# 50%     38667.000000       9.000000      1973.000000  1.111584e+08
# 75%     57072.000000      13.000000      1996.000000  1.137687e+08
# max     99998.000000     121.000000      2022.000000  1.157117e+08
#
#              noRooms          floor  baseRentRange   noRoomsRange  \
# count  268772.000000  217493.000000  268772.000000  268772.000000
# mean        2.641347       2.122583       3.765660       2.571663
# std         2.633616       3.635269       2.214247       0.937473
# min         1.000000      -1.000000       1.000000       1.000000
# 25%         2.000000       1.000000       2.000000       2.000000
# 50%         3.000000       2.000000       3.000000       3.000000
# 75%         3.000000       3.000000       5.000000       3.000000
# max       999.990000     999.000000       9.000000       5.000000
#
#        livingSpaceRange  yearConstructedRange
# count     268772.000000         211765.000000
# mean           3.070971              3.714509
# std            1.407025              2.738046
# min            1.000000              1.000000
# 25%            2.000000              1.000000
# 50%            3.000000              3.000000
# 75%            4.000000              5.000000
# max            7.000000              9.000000

# %%
# count NaN in each row to make sure the substitution took effect
df_trim.isna().sum()
# Out:
# regio1                      0
# baseRent                    0
# totalRent               40549
# pricetrend               1832
# livingSpace                71
# geo_plz                     0
# picturecount                0
# newlyConst                  0
# yearConstructed         57007
# scoutId                     0
# firingTypes             56927
# heatingType             44827
# hasKitchen                  0
# cellar                      0
# condition               68451
# street                      0
# lift                        0
# typeOfFlat              36598
# noRooms                     0
# floor                   51279
# balcony                     0
# garden                      0
# baseRentRange               0
# noRoomsRange                0
# livingSpaceRange            0
# yearConstructedRange    57007
# regio2                      0
# regio3                      0
# description             19738
# date                        0
# dtype: int64

# %% [markdown]
# ## 04e. Number of rooms anomalies

# %% [markdown]
# Moving on to noRooms. I'll examine anything with more than 13 rooms.

# %%
# create subset of entries with over 13 rooms
manyRooms = df_trim[df_trim['noRooms'] > 13.0]

# %%
# copy to clipboard so I can view in Excel
manyRooms.to_clipboard()

# %%
# view noRooms stats before corrections
df_trim['noRooms'].describe()
# Out:
# count    268772.000000
# mean          2.641347
# std           2.633616
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max         999.990000
# Name: noRooms, dtype: float64

# %%
df_trim.loc[df_trim['livingSpaceRange'] == 2, 'noRooms'].median()
# Out:
# 2.0

# %%
df_trim.loc[df_trim['livingSpaceRange'] == 3, 'noRooms'].median()
# Out:
# 3.0

# %%
df_trim.loc[df_trim['livingSpaceRange'] == 1, 'noRooms'].median()
# Out:
# 1.0

# %% [markdown]
# I decided to correct 30 noRooms values with the value stated in the description or the median value for the given livingSpaceRange.

# %%
df_trim = df_trim.replace({'noRooms': {79: 6, 120: 3, 23:3, 16: 2, 100: 3, 32:3, 560: 2, 160: 3, 30: 3, 230: 2, 65: 1, 21: 2, 999.99: 3, 80: 3, 75.5: 2, 50: 2, 25: 2, 99.5: 3, 200: 2, 140: 1, 99:2, 305: 3,22: 2, 45: 3}})

# %%
df_trim['noRooms'].describe()
# Out:
# count    268772.000000
# mean          2.627874
# std           0.982793
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max          18.000000
# Name: noRooms, dtype: float64

# %% [markdown]
# ## 04f. Floor anomalies

# %% [markdown]
# Last but not least, I'll deal with the suspiciously high units. Anything above the 20th floor seems like a good start.

# %%
# create subset of entries with over 20 floors
manyFloors = df_trim[df_trim['floor'] > 20.0]

# %%
df_trim['floor'].describe()
# Out:
# count    217493.000000
# mean          2.122583
# std           3.635269
# min          -1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max         999.000000
# Name: floor, dtype: float64

# %%
# copy to clipboard so I can view in Excel, again using the description column to make a judgment
manyFloors.to_clipboard()

# %%
# calculate median for each region with incorrect floor numbers
df_trim.loc[df_trim['regio1'] == 'Sachsen', 'floor'].median()
# Out:
# 2.0

# %%
df_trim.loc[df_trim['regio1'] == 'Hessen', 'floor'].median()
# Out:
# 2.0

# %%
df_trim.loc[df_trim['regio1'] == 'Bayern', 'floor'].median()
# Out:
# 2.0

# %%
df_trim.loc[df_trim['regio1'] == 'Brandenburg', 'floor'].median()
# Out:
# 2.0

# %%
df_trim.loc[df_trim['regio1'] == 'Thüringen', 'floor'].median()
# Out:
# 2.0

# %%
df_trim.loc[df_trim['regio1'] == 'Berlin', 'floor'].median()
# Out:
# 2.0

# %%
# replace incorrect floor values
df_trim = df_trim.replace({'floor': {45: 4, 80: 2, 83: 4, 98: 2, 99: 2, 104: 0, 105: 2, 124: 2, 133: 2, 134: 2, 135: 2, 136: 2, 137: 2, 138: 2, 139: 2, 390: 0, 645: 2, 650: 2, 999: 2}})

# %%
df_trim['floor'].describe()
# Out:
# count    217493.000000
# mean          2.098114
# std           1.660336
# min          -1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max          41.000000
# Name: floor, dtype: float64

# %%
df_trim['floor'].value_counts()
# Out:
#  1.0     64116
#  2.0     56952
#  3.0     37872
#  0.0     24597
#  4.0     19953
#  5.0      7987
#  6.0      2493
#  7.0      1031
#  8.0       578
#  9.0       427
#  10.0      363
# -1.0       311
#  11.0      236
#  12.0      144
#  13.0      133
#  14.0      110
#  15.0       61
#  16.0       34
#  17.0       28
#  19.0       15
#  21.0       12
#  18.0       11
#  20.0       10
#  22.0        4
#  24.0        3
#  23.0        2
#  26.0        2
#  29.0        2
#  32.0        1
#  25.0        1
#  37.0        1
#  31.0        1
#  41.0        1
#  36.0        1
# Name: floor, dtype: int64

# %% [markdown]
# ## 04g. PLZ anomalies

# %%
# view entries where PLZ has fewer than five digits
df_trim[df_trim['geo_plz'] < 10000]
# Out:
#                 regio1  baseRent  totalRent  pricetrend  livingSpace  geo_plz  \
# 2              Sachsen     965.0     1300.0        2.72        83.80     1097
# 3              Sachsen     343.0        NaN        1.53        58.15     9599
# 6              Sachsen     310.0      380.0        1.01        62.00     9599
# 10             Sachsen     219.0      307.0        0.21        40.20     9130
# 11             Sachsen     400.0      555.0        0.98        80.00     9669
# ...                ...       ...        ...         ...          ...      ...
# 268833         Sachsen     300.0        NaN        2.10       102.00     2708
# 268834         Sachsen     440.0      610.0        1.92        70.49     8396
# 268836  Sachsen_Anhalt     520.0      820.0        0.00       115.00     6268
# 268842         Sachsen     300.0      440.0        0.54        59.89     8058
# 268843         Sachsen     248.0      368.0        2.00        55.00     9119
#
#         picturecount  newlyConst  yearConstructed    scoutId  \
# 2                  8        True           2019.0  113147523
# 3                  9       False           1964.0  108890903
# 6                  9       False              NaN  114391930
# 10                11       False           1930.0  112923517
# 11                 9       False           1892.0  109842225
# ...              ...         ...              ...        ...
# 268833            11       False           1873.0  114637314
# 268834             3       False              NaN   99131525
# 268836            17       False              NaN  112441878
# 268842             7       False              NaN  111857041
# 268843            12       False           1930.0   91110231
#
#              firingTypes                     heatingType  hasKitchen  cellar  \
# 2                    NaN                   floor_heating       False    True
# 3       district_heating                district_heating       False   False
# 6                    NaN  self_contained_central_heating       False    True
# 10                   gas                             NaN       False    True
# 11                   gas                 central_heating       False    True
# ...                  ...                             ...         ...     ...
# 268833               NaN                             NaN       False   False
# 268834               gas                 central_heating       False    True
# 268836               gas                 central_heating        True   False
# 268842               NaN                             NaN        True   False
# 268843               gas                 central_heating       False    True
#
#               condition                       street   lift  typeOfFlat  \
# 2        first_time_use                    Turnerweg   True   apartment
# 3                   NaN  Gl&uuml;ck-Auf-Stra&szlig;e  False       other
# 6       fully_renovated                   Am Bahnhof  False         NaN
# 10                  NaN           Hofer Stra&szlig;e  False   apartment
# 11            well_kept               no_information  False         NaN
# ...                 ...                          ...    ...         ...
# 268833      refurbished               no_information  False   apartment
# 268834        well_kept               no_information  False         NaN
# 268836        well_kept                    Lederberg  False  maisonette
# 268842              NaN   M&uuml;hlpfortstra&szlig;e  False  maisonette
# 268843       negotiable            Neefestra&szlig;e  False   apartment
#
#         noRooms  floor  balcony  garden  baseRentRange  noRoomsRange  \
# 2           3.0    3.0     True   False              6             3
# 3           3.0    3.0     True   False              2             3
# 6           2.0    1.0    False    True              2             2
# 10          2.0    3.0     True   False              1             2
# 11          3.0    1.0    False    True              2             3
# ...         ...    ...      ...     ...            ...           ...
# 268833      4.0    NaN    False   False              1             4
# 268834      3.0    0.0     True   False              3             3
# 268836      4.0    NaN    False   False              4             4
# 268842      2.0    3.0    False   False              1             2
# 268843      2.0    1.0     True    True              1             2
#
#         livingSpaceRange  yearConstructedRange               regio2  \
# 2                      4                   9.0              Dresden
# 3                      2                   2.0  Mittelsachsen_Kreis
# 6                      3                   NaN  Mittelsachsen_Kreis
# 10                     1                   1.0             Chemnitz
# 11                     3                   1.0  Mittelsachsen_Kreis
# ...                  ...                   ...                  ...
# 268833                 5                   1.0        Görlitz_Kreis
# 268834                 3                   NaN        Zwickau_Kreis
# 268836                 5                   NaN           Saalekreis
# 268842                 2                   NaN              Zwickau
# 268843                 2                   1.0             Chemnitz
#
#                             regio3  \
# 2       Äußere_Neustadt_Antonstadt
# 3                         Freiberg
# 6                         Freiberg
# 10                      Sonnenberg
# 11             Frankenberg/Sachsen
# ...                            ...
# 268833                       Löbau
# 268834                  Waldenburg
# 268836                    Querfurt
# 268842                Nordvorstadt
# 268843                      Kappel
#
#                                               description   date
# 2       Der Neubau entsteht im Herzen der Dresdner Neu...  Oct19
# 3       Abseits von Lärm und Abgasen in Ihre neue Wohn...  May19
# 6       Am Bahnhof 14 in Freiberg\nHeizkosten und Warm...  Feb20
# 10      Gemütliche 2-Raum Wohnung in Chemnitz.  komple...  Oct19
# 11      Gern möchten wir Ihnen diese 3-Zimmer-Wohnung ...  May19
# ...                                                   ...    ...
# 268833  Vermietet werden 3 Wohneinheiten im 1.OG, 2.OG...  Feb20
# 268834  Die Wohnung befindet sich in einem gewachsenen...  Sep18
# 268836  Der Eingang der 4-Raum-Maisonetten-Wohnung bef...  Oct19
# 268842                                                NaN  Oct19
# 268843  Es handelt sich um ein Mehrfamilienhaus mit 6 ...  Sep18
#
# [75337 rows x 30 columns]

# %% [markdown]
# Note: The results indicate the four-digit PLZs are largely from the Sachsen region, where postal codes have leading zeroes. But when I went to map this dataset later, I realized there were 10 zipcodes that were missing a digit in error. Correcting those now...

# %%
df_trim = df_trim.replace({'geo_plz': {2122: 21224, 3017: 30177, 3118: 38118, 3821: 18311, 4414: 44141, 4428: 44289, 4730: 52159, 5931: 49716, 6910: 69120, 8382: 88079}})

# %% [markdown]
# ## 04h. Update and copy descriptive stats

# %%
stats = df_trim.describe()

# %%
stats.to_clipboard()

# %% [markdown]
# # 05. Address mixed-type data

# %%
# display data types
df_trim.dtypes
# Out:
# regio1                   object
# baseRent                float64
# totalRent               float64
# pricetrend              float64
# livingSpace             float64
# geo_plz                   int64
# picturecount              int64
# newlyConst                 bool
# yearConstructed         float64
# scoutId                   int64
# firingTypes              object
# heatingType              object
# hasKitchen                 bool
# cellar                     bool
# condition                object
# street                   object
# lift                       bool
# typeOfFlat               object
# noRooms                 float64
# floor                   float64
# balcony                    bool
# garden                     bool
# baseRentRange             int64
# noRoomsRange              int64
# livingSpaceRange          int64
# yearConstructedRange    float64
# regio2                   object
# regio3                   object
# description              object
# date                     object
# dtype: object

# %%
for col in df_trim.columns.tolist():
  weird = (df_trim[[col]].applymap(type) != df_trim[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_trim[weird]) > 0:
    print (col)
# Out:
# firingTypes
# heatingType
# condition
# typeOfFlat
# description

# %% [markdown]
# We have mixed data types in the five columns listed above. I also need to change scoutId to a string because this number is a unique identifier that doesn't warrant analysis, and I'm changing date to a string for now.

# %%
# identify the appropriate data type for the column, then run this command to change the type of any non-conforming values

df_trim['firingTypes'] = df_trim['firingTypes'].astype('str')
df_trim['heatingType'] = df_trim['heatingType'].astype('str')
df_trim['condition'] = df_trim['condition'].astype('str')
df_trim['typeOfFlat'] = df_trim['typeOfFlat'].astype('str')
df_trim['description'] = df_trim['description'].astype('str')
df_trim['date'] = df_trim['date'].astype('str')
df_trim['scoutId'] = df_trim['scoutId'].astype('str')

# %%
# check again for mixed-type columns
for col in df_trim.columns.tolist():
  weird = (df_trim[[col]].applymap(type) != df_trim[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_trim[weird]) > 0:
    print (col)

# %% [markdown]
# Now I'll change the date column to datetime format to make sure I can use it for time-based analysis later. First I check the possible values for this column, then replace them with YYYYMMDD values, then convert to datetime format.

# %%
df['date'].unique()
# Out:
# array(['May19', 'Oct19', 'Feb20', 'Sep18'], dtype=object)

# %%
df_trim = df_trim.replace({'date': {'May19': 20190510, 'Sep18': 20180922, 'Feb20': 20200201, 'Oct19': 20191008}})

# %%
df_trim['date'] = pd.to_datetime(df_trim['date'], format= '%Y%m%d')

# %% [markdown]
# Finally, I'll check the data types again to make sure everything looks in order.

# %%
df_trim.dtypes
# Out:
# regio1                          object
# baseRent                       float64
# totalRent                      float64
# pricetrend                     float64
# livingSpace                    float64
# geo_plz                          int64
# picturecount                     int64
# newlyConst                        bool
# yearConstructed                float64
# scoutId                         object
# firingTypes                     object
# heatingType                     object
# hasKitchen                        bool
# cellar                            bool
# condition                       object
# street                          object
# lift                              bool
# typeOfFlat                      object
# noRooms                        float64
# floor                          float64
# balcony                           bool
# garden                            bool
# baseRentRange                    int64
# noRoomsRange                     int64
# livingSpaceRange                 int64
# yearConstructedRange           float64
# regio2                          object
# regio3                          object
# description                     object
# date                    datetime64[ns]
# dtype: object

# %% [markdown]
# # 06. Check for duplicates

# %%
df_dups = df_trim[df_trim.duplicated()]

# %%
df_dups
# empty = no duplicates
# Out:
# Empty DataFrame
# Columns: [regio1, baseRent, totalRent, pricetrend, livingSpace, geo_plz, picturecount, newlyConst, yearConstructed, scoutId, firingTypes, heatingType, hasKitchen, cellar, condition, street, lift, typeOfFlat, noRooms, floor, balcony, garden, baseRentRange, noRoomsRange, livingSpaceRange, yearConstructedRange, regio2, regio3, description, date]
# Index: []

# %% [markdown]
# # 07. Create new price/unit variable

# %%
df_trim['price/unit'] = df_trim['totalRent']/df['livingSpace']

# %% [markdown]
# # 08. Final checks and export

# %%
# check the header one last time
df_trim.head()
# Out:
#                 regio1  baseRent  totalRent  pricetrend  livingSpace  geo_plz  \
# 0  Nordrhein_Westfalen     595.0      840.0        4.62        86.00    44269
# 1      Rheinland_Pfalz     800.0        NaN        3.47        89.00    67459
# 2              Sachsen     965.0     1300.0        2.72        83.80     1097
# 3              Sachsen     343.0        NaN        1.53        58.15     9599
# 4               Bremen     765.0      903.0        2.46        84.97    28213
#
#    picturecount  newlyConst  yearConstructed    scoutId       firingTypes  \
# 0             6       False           1965.0   96107057               oil
# 1             8       False           1871.0  111378734               gas
# 2             8        True           2019.0  113147523               nan
# 3             9       False           1964.0  108890903  district_heating
# 4            19       False           1950.0  114751222               gas
#
#                       heatingType  hasKitchen  cellar       condition  \
# 0                 central_heating       False    True       well_kept
# 1  self_contained_central_heating       False   False     refurbished
# 2                   floor_heating       False    True  first_time_use
# 3                district_heating       False   False             nan
# 4  self_contained_central_heating       False   False     refurbished
#
#                         street   lift    typeOfFlat  noRooms  floor  balcony  \
# 0   Sch&uuml;ruferstra&szlig;e  False  ground_floor      4.0    1.0    False
# 1               no_information  False  ground_floor      3.0    NaN     True
# 2                    Turnerweg   True     apartment      3.0    3.0     True
# 3  Gl&uuml;ck-Auf-Stra&szlig;e  False         other      3.0    3.0     True
# 4  Hermann-Henrich-Meier-Allee  False     apartment      3.0    1.0     True
#
#    garden  baseRentRange  noRoomsRange  livingSpaceRange  \
# 0    True              4             4                 4
# 1   False              5             3                 4
# 2   False              6             3                 4
# 3   False              2             3                 2
# 4   False              5             3                 4
#
#    yearConstructedRange               regio2                      regio3  \
# 0                   2.0             Dortmund                     Schüren
# 1                   1.0    Rhein_Pfalz_Kreis              Böhl_Iggelheim
# 2                   9.0              Dresden  Äußere_Neustadt_Antonstadt
# 3                   2.0  Mittelsachsen_Kreis                    Freiberg
# 4                   1.0               Bremen           Neu_Schwachhausen
#
#                                          description       date  price/unit
# 0  Die ebenerdig zu erreichende Erdgeschosswohnun... 2019-05-10    9.767442
# 1  Alles neu macht der Mai – so kann es auch für ... 2019-05-10         NaN
# 2  Der Neubau entsteht im Herzen der Dresdner Neu... 2019-10-08   15.513126
# 3  Abseits von Lärm und Abgasen in Ihre neue Wohn... 2019-05-10         NaN
# 4  Es handelt sich hier um ein saniertes Mehrfami... 2020-02-01   10.627280

# %%
# check shape
df_trim.shape
# Out:
# (268772, 31)

# %%
# export to csv
# be sure to specify utf8 encoding to preserve special characters
df_trim.to_csv(os.path.join(r'..\cleaned data','rent_cleaned.csv'), encoding = 'utf8', index=False)
